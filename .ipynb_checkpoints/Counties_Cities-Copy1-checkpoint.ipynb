# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import gmaps
from ipywidgets.embed import embed_minimal_html
import requests
import pprint

# %%
url = "cal.csv"
cal = pd.read_csv(url)
cal
# Out:
#         Unnamed: 0  Severity           Start_Time  Start_Lat   Start_Lng  \
# 0              728         3  2016-06-21 10:34:40  38.085300 -122.233017
# 1              729         3  2016-06-21 10:30:16  37.631813 -122.084167
# 2              730         2  2016-06-21 10:49:14  37.896564 -122.070717
# 3              731         3  2016-06-21 10:41:42  37.334255 -122.032471
# 4              732         2  2016-06-21 10:16:26  37.250729 -121.910713
# ...            ...       ...                  ...        ...         ...
# 663199     2974330         2  2019-08-23 18:03:25  34.002480 -117.379360
# 663200     2974331         2  2019-08-23 19:11:30  32.766960 -117.148060
# 663201     2974332         2  2019-08-23 19:00:21  33.775450 -117.847790
# 663202     2974333         2  2019-08-23 19:00:21  33.992460 -118.403020
# 663203     2974334         2  2019-08-23 18:52:06  34.133930 -117.230920
#
#                      Street          City          County State Zipcode  \
# 0               Magazine St       Vallejo          Solano    CA   94591
# 1                   I-880 N       Hayward         Alameda    CA   94544
# 2                   I-680 N  Walnut Creek    Contra Costa    CA   94595
# 3            N De Anza Blvd     Cupertino     Santa Clara    CA   95014
# 4       Norman Y Mineta Hwy      San Jose     Santa Clara    CA   95118
# ...                     ...           ...             ...   ...     ...
# 663199         Pomona Fwy E     Riverside       Riverside    CA   92501
# 663200                I-8 W     San Diego       San Diego    CA   92108
# 663201     Garden Grove Fwy        Orange          Orange    CA   92866
# 663202      San Diego Fwy S   Culver City     Los Angeles    CA   90230
# 663203             CA-210 W      Highland  San Bernardino    CA   92346
#
#         Temperature(F) Weather_Condition
# 0                 75.0             Clear
# 1                 75.0             Clear
# 2                 82.9             Clear
# 3                 75.9             Clear
# 4                 75.2             Clear
# ...                ...               ...
# 663199            86.0              Fair
# 663200            70.0              Fair
# 663201            73.0     Partly Cloudy
# 663202            71.0              Fair
# 663203            79.0              Fair
#
# [663204 rows x 12 columns]

# %%
county_count = cal.groupby('County').count()
city_count = cal.groupby('City').count()

city_count
# Out:
#               Unnamed: 0  Severity  Start_Time  Start_Lat  Start_Lng  Street  \
# City
# Acampo               398       398         398        398        398     398
# Acton               1298      1298        1298       1298       1298    1298
# Adelanto              60        60          60         60         60      60
# Adin                   1         1           1          1          1       1
# Agoura Hills         656       656         656        656        656     656
# ...                  ...       ...         ...        ...        ...     ...
# Yuba City            233       233         233        233        233     233
# Yucaipa              141       141         141        141        141     141
# Yucca Valley          38        38          38         38         38      38
# Zamora                36        36          36         36         36      36
# Zenia                  2         2           2          2          2       2
#
#               County  State  Zipcode  Temperature(F)  Weather_Condition
# City
# Acampo           398    398      398             397                397
# Acton           1298   1298     1298            1297               1297
# Adelanto          60     60       60              19                 57
# Adin               1      1        1               1                  1
# Agoura Hills     656    656      656             655                655
# ...              ...    ...      ...             ...                ...
# Yuba City        233    233      233             232                231
# Yucaipa          141    141      141             141                141
# Yucca Valley      38     38       38              38                 38
# Zamora            36     36       36              36                 36
# Zenia              2      2        2               2                  2
#
# [1157 rows x 11 columns]

# %%
# California counties by number of accidents (normalized by population)
counties = county_count.Severity.sort_values(ascending = False)
top_counties = counties.nlargest(n=10)

counties_plot = top_counties.plot(kind = 'bar', title = 'Accidents by County: California')

# %%
# # Import API key
# from api_keys import c_key

# %%
# to adjust for population we will need the data for population from the census
# COUNTY	County FIPS code https://api.census.gov/data/2016/pep/population/variables.html
# 050 is State > County https://api.census.gov/data/2016/pep/population
# https://api.census.gov/data/2016/pep/population?get=GEONAME,POP&for=county:*&in=state:*

c_key = "4ddfbbf4d6ce095e4b374bbb3c212ca88cb3027c"
state = "06"
county = "001"

pop_url = "https://api.census.gov/data/2016/pep/population"

query_url = f"{pop_url}?get=GEONAME,POP&for=place:*&in=state:06&key={c_key}"
# query_url = f"{pop_url}?get=GEONAME,POP&for=county:*&in=state:06&key={c_key}"

GEONAME = []
POP = [] 
state = [] 
place = []

# https://api.census.gov/data/2016/pep/population?get=GEONAME,POP&for=place:*&in=state:01%20county:003
# https://api.census.gov/data/2016/pep/population?get=GEONAME,POP&for=county:*&in=state:*
response = requests.get(query_url)

if response:
#     Debugging print statements  
    print("GET URL: " + response.url)
    print("STATUS CODE: " + str(response.status_code))
    response_json = response.json()
#     print(response_json)
  
    for data in response_json:
        
        GEONAME.append(data[0])    
        POP.append(data[1])
        state.append(data[2])
        place.append(data[3])
 
    
else:
    print("API REQUEST ERROR")
    print("STATUS CODE: " + str(response.status_code))
GEONAME = GEONAME[1:]
POP = POP[1:]
state = state[1:]
place = place[1:]

print(GEONAME)
# Out:
# GET URL: https://api.census.gov/data/2016/pep/population?get=GEONAME,POP&for=place:*&in=state:06&key=4ddfbbf4d6ce095e4b374bbb3c212ca88cb3027c
# STATUS CODE: 200
# ['Arvin city, California', 'Atascadero city, California', 'Atherton town, California', 'Atwater city, California', 'Auburn city, California', 'Avalon city, California', 'Avenal city, California', 'Azusa city, California', 'Bakersfield city, California', 'Baldwin Park city, California', 'Banning city, California', 'Barstow city, California', 'Beaumont city, California', 'Bell city, California', 'Bellflower city, California', 'Bell Gardens city, California', 'Belmont city, California', 'Belvedere city, California', 'Benicia city, California', 'Berkeley city, California', 'Beverly Hills city, California', 'Big Bear Lake city, California', 'Biggs city, California', 'Bishop city, California', 'Blue Lake city, California', 'Blythe city, California', 'Bradbury city, California', 'Brawley city, California', 'Brea city, California', 'Brentwood city, California', 'Brisbane city, California', 'Buellton city, California', 'Buena Park city, California', 'Burbank city, California', 'Burlingame city, California', 'Adelanto city, California', 'Agoura Hills city, California', 'Alameda city, California', 'Albany city, California', 'Alhambra city, California', 'Aliso Viejo city, California', 'Alturas city, California', 'Amador City city, California', 'American Canyon city, California', 'Anaheim city, California', 'Anderson city, California', 'Angels city, California', 'Antioch city, California', 'Apple Valley town, California', 'Arcadia city, California', 'Arcata city, California', 'Arroyo Grande city, California', 'Artesia city, California', 'Tehachapi city, California', 'Tehama city, California', 'Temecula city, California', 'Temple City city, California', 'Thousand Oaks city, California', 'Tiburon town, California', 'Torrance city, California', 'Tracy city, California', 'Trinidad city, California', 'Truckee town, California', 'Tulare city, California', 'Tulelake city, California', 'Turlock city, California', 'Tustin city, California', 'Twentynine Palms city, California', 'Ukiah city, California', 'Union City city, California', 'Upland city, California', 'Vacaville city, California', 'Vallejo city, California', 'Vernon city, California', 'Victorville city, California', 'Villa Park city, California', 'Visalia city, California', 'Vista city, California', 'Walnut city, California', 'Walnut Creek city, California', 'Wasco city, California', 'Waterford city, California', 'Watsonville city, California', 'Weed city, California', 'West Covina city, California', 'West Hollywood city, California', 'Westlake Village city, California', 'Westminster city, California', 'Westmorland city, California', 'West Sacramento city, California', 'Wheatland city, California', 'Whittier city, California', 'Wildomar city, California', 'Williams city, California', 'Willits city, California', 'Willows city, California', 'Windsor town, California', 'Winters city, California', 'Woodlake city, California', 'Woodland city, California', 'Woodside town, California', 'Yorba Linda city, California', 'Yountville city, California', 'Yreka city, California', 'Yuba City city, California', 'Yucaipa city, California', 'Yucca Valley town, California', 'Saratoga city, California', 'Sausalito city, California', 'Scotts Valley city, California', 'Seal Beach city, California', 'Seaside city, California', 'Sebastopol city, California', 'Dublin city, California', 'Dunsmuir city, California', 'East Palo Alto city, California', 'Eastvale city, California', 'El Cajon city, California', 'El Centro city, California', 'Lakeport city, California', 'Lakewood city, California', 'La Mesa city, California', 'La Mirada city, California', 'Lancaster city, California', 'La Palma city, California', 'Palm Springs city, California', 'Palo Alto city, California', 'Palos Verdes Estates city, California', 'Paradise town, California', 'Paramount city, California', 'Parlier city, California', 'Selma city, California', 'Shafter city, California', 'Shasta Lake city, California', 'Sierra Madre city, California', 'Sig ...

# %%
# Take the lists and make a dictionary
census_dict = {
    "City": GEONAME,
    "Population": POP,
    "State": state,
    "County": place
}

# Make a data frame from the dictionary
census_data = pd.DataFrame(census_dict)

census_data
# Out:
#                               City Population State County
# 0           Arvin city, California      21086    06  02924
# 1      Atascadero city, California      30330    06  03064
# 2        Atherton town, California       7207    06  03092
# 3         Atwater city, California      29270    06  03162
# 4          Auburn city, California      13963    06  03204
# ..                             ...        ...   ...    ...
# 477   Santa Maria city, California     106290    06  69196
# 478  Santa Monica city, California      92478    06  70000
# 479   Santa Paula city, California      30335    06  70042
# 480    Santa Rosa city, California     175155    06  70098
# 481        Santee city, California      57834    06  70224
#
# [482 rows x 4 columns]

# %%
# Top 5 Cities that have the most accidents
cities_count = city_count.Severity.sort_values(ascending = False)
top_cities = cities_count.nlargest(n =10)

cities_plot = top_cities.plot(kind = 'bar', title = 'Accidents by City: California')

# %%
census_data['Population'] = census_data['Population'].astype(float)

census_data.sort_values('Population', ascending = False)
# Out:
#                                City  Population State County
# 217    Los Angeles city, California   3976322.0    06  44000
# 364      San Diego city, California   1406630.0    06  66000
# 406       San Jose city, California   1025350.0    06  68000
# 384  San Francisco city, California    870887.0    06  67000
# 233         Fresno city, California    522053.0    06  27000
# ..                              ...         ...   ...    ...
# 363      Sand City city, California       383.0    06  65112
# 61        Trinidad city, California       359.0    06  80448
# 396       Industry city, California       205.0    06  36490
# 42     Amador City city, California       191.0    06  01514
# 73          Vernon city, California       113.0    06  82422
#
# [482 rows x 4 columns]

# %%
census_data[['City','State']] = census_data.City.str.split(",",expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9bc6078cc180> in <module>
# ----> 1 census_data[['City','State']] = census_data.City.str.split(",",expand=True)
#       2 # Visualize the data frame
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3467             self._setitem_frame(key, value)
#    3468         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3469             self._setitem_array(key, value)
#    3470         else:
#    3471             # set column
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3490             if isinstance(value, DataFrame):
#    3491                 if len(value.columns) != len(key):
# -> 3492                     raise ValueError("Columns must be same length as key")
#    3493                 for k1, k2 in zip(key, value.columns):
#    3494                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
census_data["City2"] = census_data.City.str.slice(0,4,1)
census_data["City2"] = census_data.City.str.slice(0,-5,1)

census_data
# Out:
#                   City  Population        State County         City2
# 0           Arvin city     21086.0   California  02924         Arvin
# 1      Atascadero city     30330.0   California  03064    Atascadero
# 2        Atherton town      7207.0   California  03092      Atherton
# 3         Atwater city     29270.0   California  03162       Atwater
# 4          Auburn city     13963.0   California  03204        Auburn
# ..                 ...         ...          ...    ...           ...
# 477   Santa Maria city    106290.0   California  69196   Santa Maria
# 478  Santa Monica city     92478.0   California  70000  Santa Monica
# 479   Santa Paula city     30335.0   California  70042   Santa Paula
# 480    Santa Rosa city    175155.0   California  70098    Santa Rosa
# 481        Santee city     57834.0   California  70224        Santee
#
# [482 rows x 5 columns]

# %%
box_cities = top_cities.plot(kind = 'box', title = 'Accidents by City: California')

# %%
# Import API key
from api_keys import g_key

# %%
#State heat map with markers for accidents
gmaps.configure(api_key=g_key)

# Store latitude and longitude in locations
locations = cal[["Start_Lat", "Start_Lng"]]

accidents = cal['Severity']

# %%
cal_test = cal[0:100]
cal_test

# %%
# Plot Heatmap
fig  = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, dissipating=True, max_intensity=10, point_radius=1)

# Add layer
fig.add_layer(heat_layer)

#Display figure
fig

# %%
embed_minimal_html('export.html', views=[fig])
