# %%
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt

# %%
#usa = pd.read_csv('US_Accidents_Dec19 2.csv')

# %%
#usa.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
#cal_weather = usa[usa['State'] == 'CA']

# %%
# cal_weather = cal_weather[['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng',
#                            'Description', 'Street', 'City', 'County', 'State',
#                            'Temperature(F)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)','Precipitation(in)']]

# %%
#cal_weather.to_csv('cal_weather.csv', index=False)

# %%
cal_weather = pd.read_csv('cal_weather.csv')

# %%
cal_weather.head()
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng  \
# 0         3  2016-06-21 10:34:40  38.085300 -122.233017
# 1         3  2016-06-21 10:30:16  37.631813 -122.084167
# 2         2  2016-06-21 10:49:14  37.896564 -122.070717
# 3         3  2016-06-21 10:41:42  37.334255 -122.032471
# 4         2  2016-06-21 10:16:26  37.250729 -121.910713
#
#                                          Description               Street  \
# 0  Right hand shoulder blocked due to accident on...          Magazine St
# 1  Accident on I-880 Northbound at Exit 26 Tennys...              I-880 N
# 2  Right lane blocked due to accident on CA-24 We...              I-680 N
# 3  #4 &amp; HOV lane blocked due to accident on I...       N De Anza Blvd
# 4  Right hand shoulder blocked due to accident on...  Norman Y Mineta Hwy
#
#            City        County State  Temperature(F)  Pressure(in)  \
# 0       Vallejo        Solano    CA            75.0         30.00
# ...

# %%
cal_weather.describe()
# Out:
#             Severity      Start_Lat      Start_Lng  Temperature(F)  \
# count  663204.000000  663204.000000  663204.000000   648079.000000
# mean        2.337331      35.504755    -119.478862       65.681507
# std         0.493503       2.024029       1.955176       12.472955
# min         1.000000      32.542587    -124.367607      -29.900000
# 25%         2.000000      33.953853    -121.686463       57.000000
# 50%         2.000000      34.156670    -118.371122       64.400000
# 75%         3.000000      37.688770    -117.926880       73.400000
# max         4.000000      42.005278    -114.481224      127.400000
#
#         Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  651962.000000   650008.000000    534398.000000      195589.000000
# mean       29.850822        9.167930         7.446220           0.008646
# std         0.478655        2.234368         5.899021           0.066014
# ...

# %%
temp_group = cal_weather.groupby('Temperature(F)').count()

# %%
temps = temp_group.index.get_level_values(0).array

# %%
plt.scatter(temps, temp_group.Start_Time)

# %%
la = cal_weather[cal_weather['County'] == 'Santa Clara']

# %%
la.describe()
# Out:
#            Severity     Start_Lat     Start_Lng  Temperature(F)  Pressure(in)  \
# count  34521.000000  34521.000000  34521.000000    32869.000000  33597.000000
# mean       2.234698     37.312311   -121.913598       62.402291     29.984806
# std        0.441295      0.102211      0.142426       10.628559      0.214924
# min        1.000000     36.928719   -122.193275       28.400000      9.900000
# 25%        2.000000     37.275826   -121.990417       55.000000     29.900000
# 50%        2.000000     37.332981   -121.926440       61.000000     29.980000
# 75%        2.000000     37.378471   -121.870255       69.100000     30.080000
# max        4.000000     37.473393   -121.212271      113.000000     30.600000
#
#        Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count    33047.000000     27769.000000        8277.000000
# mean         9.468475         8.373690           0.007796
# std          1.682302         5.084498           0.026658
# ...

# %%
la_temp = la.groupby('Temperature(F)').count()

# %%
temp = la_temp.index.get_level_values(0).array

# %%
la_temp
# Out:
#                 Severity  Start_Time  Start_Lat  Start_Lng  Description  \
# Temperature(F)
# 28.4                   4           4          4          4            4
# 30.2                   9           9          9          9            9
# 32.0                  17          17         17         17           17
# 33.1                   2           2          2          2            2
# 33.8                  16          16         16         16           16
# ...                  ...         ...        ...        ...          ...
# 102.2                  1           1          1          1            1
# 105.1                  1           1          1          1            1
# 105.8                  1           1          1          1            1
# 107.6                  7           7          7          7            7
# 113.0                  1           1          1          1            1
#
#                 Street  City  County  State  Pressure(in)  Visibility(mi)  \
# ...

# %%
plt.scatter(temp, la_temp.Severity)
